# %% [markdown]
# # 1.2 Proteínas

# %% [markdown]
# A fim de obter uma impressão da complexidade da tarefa para descrever o relacionamento entre a composição química, a estrutura geométrica e a função das macros individuais moléculas, vamos agora olhar mais de perto em um dos exemplos mais proeminentes que representa uma classe inteira de biomoléculas: proteínas.
