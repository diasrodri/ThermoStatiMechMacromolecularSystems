# %% [markdown]
# #Termodinamica e Mechanica Estatística de sistemas Macromoleculares
# ##Prof. Dr. Rodrigo ALves Dias

# %% [markdown]
# #Referencia Bibliografica:
#
# > Thermodynamics and Statistical Mechanics of Macromolecular Systems
#
# >DOI={10.1017/CBO9781139028516},
#
# >publisher={Cambridge University Press},
#
# >author={Bachmann, Michael}, y
#
# >year={2014}

# %% [markdown]
# #1. Introdução
# 1.1 Relevância da pesquisa biomolecular
#
# #1.2 Proteínas
# 1.2.1 A tríade de sequência de aminoácidos, estrutura e função
#
# 1.2.2 Síntese ribossômica de proteínas
#
# 1.2.3 Da sequência para a função: O processo de dobragem de proteínas
#
# # 1.3 Modelagem molecular
# 1.3.1 Ligações covalentes
#
# 1.3.2 Interações não covalentes efetivas e modelagem nanoscópica: Em direção a uma representação semiclássica de todos os átomos
#
# # 1.4 Modelagem de peptídeos com todos os átomo
#
# # 1.5 A perspectiva mesoscópica
#
# 1.5.1 Por que granulação grossa(coarse-graining) ...? A origem da força hidrofóbica
#
# 1.5.2 Modelagem polar hidrofóbica de granulação grossa
#
# # 1.6 Polímeros
# 1.6.1 DNA e RNA
#
# 1.6.2 Modelando o DNA livre
#
# 1.6.3 Polímeros flexíveis e auto-interativos
#
# 1.6.4 Polímeros elásticos

# %% [markdown]
# #2 Statistical mechanics: A modern review
#
# ##The theory of everything
#
# ##Thermodynamics and statistical mechanics
# 2.2.1 The thermodynamic limit
#
# 2.2.2 Thermodynamics of closed systems: The canonical ensemble
#
# 2.2.3 Thermodynamic equilibrium and the statistical nature of entropy
#
# ##Thermal fluctuations and the statistical path integral
#
# ##Phase and pseudophase transitions
#
# ##Relevant degrees of freedom
# 2.5.1 Coarse-grained modeling on mesoscopic scales
#
# 2.5.2 Macroscopic relevant degrees of freedom: The free-energy landscape
#
# ##Kinetic free-energy barrier and transition state
#
# ##Microcanonical statistical analysis
# 2.7.1 Temperature as a derived quantity
#
# 2.7.2 Identification of first-order transitions by Maxwell construction
#
# 2.7.3 Systematic classification of transitions by inflection-point analysis

# %% [markdown]
# #3 The complexity of minimalistic lattice models for protein folding
# 3.1 Evolutionary aspects
#
# 3.2 Self-avoiding walks and contact matrices
#
# 3.3 Exact statistical analysis of designing sequences
#
# 3.4 Exact density of states and thermodynamics

# %% [markdown]
# #4 Monte Carlo and chain growth methods for molecular simulations
#
# ##Introduction
#
# ##Conventional Markov-chain Monte Carlo sampling
# 4.2.1 Ergodicity and finite time series
#
# 4.2.2 Statistical error and bias
#
# 4.2.3 Binning–jackknife error analysis
#
# ##Systematic data smoothing by using Bézier curves
# 4.3.1 Construction of a Bézier curve
#
# 4.3.2 Smooth Bézier functions for discrete noisy data sets
#
# ##Markov processes and stochastic sampling strategies
# 4.4.1 Master equation
#
# 4.4.2 Selection and acceptance probabilities
#
# 4.4.3 Simple sampling
#
# 4.4.4 Metropolis sampling
#
# ##Reweighting methods
# 4.5.1 Single-histogram reweighting
#
# 4.5.2 Multiple-histogram reweighting
#
# ##Generalized-ensemble Monte Carlo methods
# 4.6.1 Replica-exchange Monte Carlo method: Parallel tempering
#
# 4.6.2 Simulated tempering
#
# 4.6.3 Multicanonical sampling
#
# 4.6.4 Wang–Landau method
#
# ##Elementary Monte Carlo updates
#
# ##Lattice polymers: Monte Carlo sampling vs. Rosenbluth chain growth
#
# ##Pruned-enriched Rosenbluth method: Go with the winners
#
# ##Canonical chain growth with PERM
#
# ##Multicanonical chain-growth algorithm
# 4.11.1 Multicanonical sampling of Rosenbluth-weighted chains
#
# 4.11.2 Iterative determination of the density of states
#
# ##Random number generators
#
# ##Molecular dynamics

# %% [markdown]
# ## 5 First insights to freezing and collapse of flexible polymers
# 5.1 Conformational transitions of flexible homopolymers
#
# ## Energetic fluctuations of finite-length polymers
# 5.2.1 Peak structure of the specific heat
# 5.2.2 Simple-cubic lattice polymers
# 5.2.3 Polymers on the face-centered cubic lattice
# ## The Θ transition
# ## Freezing and collapse in the thermodynamic limit
